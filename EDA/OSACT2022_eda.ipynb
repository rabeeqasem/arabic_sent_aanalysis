# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 

import seaborn as sns
sns.set_theme(style="darkgrid")


import spacy
from spacymoji import Emoji

import csv
import re
import pandas as pd
import emoji
import regex
from collections import Counter

from tqdm import tqdm


import os
import codecs
from wordcloud import WordCloud
import arabic_reshaper
from bidi.algorithm import get_display



import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
import nltk
from nltk.corpus import stopwords
from wordcloud import WordCloud, STOPWORDS

nltk.download('stopwords')


import plotly.graph_objects as go
import plotly.io as pio
import plotly.express as px
import plotly
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rabee\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#EXPLORATORY ARABIC OFFENSIVE LANGUAGE DATASET ANALYSIS

# %% [markdown]
# # import he data

# %%
original_ds_train = pd.read_csv("https://alt.qcri.org/resources1/OSACT2022/OSACT2022-sharedTask-train.txt", sep="\t")
original_ds_train.columns=['id','Tweet','offensive','hate_speech','VLG','VIO']
original_ds_train.shape
# Out:
# (8556, 6)

# %%
original_ds_test=pd.read_csv('https://alt.qcri.org/resources1/OSACT2022/OSACT2022-sharedTask-test-tweets.txt', sep="\t")
#original_ds_test.columns=['id','Tweet','offensive','hate_speech','VLG','VIO']
original_ds_test
# Out:
#       10158                     @USER هتهزر معايا ولا ايه 😡😡😡😡
# 0     10159           مشفتش العرض بتاعهم لا مش مهتمة لا😩🐸😂 URL
# 1     10160  RT @USER عندما تكون لوحدك تحس انك لحالك صح 😊<L...
# 2     10161  RT @USER ماشاء الله الرجال باين عليه محترم <LF...
# 3     10162                          @USER شسالفة احد يفهمني 😤
# 4     10163  @USER اقووووول استريح عاد احتفالاتنا تحط اغاني...
# ...     ...                                                ...
# 2535  12694  قله حيا وين اهلهم ذولي الله لايبلانا لهالدرجه ...
# 2536  12695                         RT @USER ثم الطحلبه🐸🐸🐸 URL
# 2537  12696     يا وجه الله 😷 من اليوم ورايح شاورما انسى 🔪 URL
# 2538  12697                    @USER متخلف حتى الحلال حرمتوه 😷
# 2539  12698  @USER حنا خقينا على بنت رئيس مو على بياع كليجا...
#
# [2540 rows x 2 columns]

# %%
#Class distribution for the L_HSAB
ax=sns.countplot(x='hate_speech', data=original_ds_train)

# %%
#renmae the cat values to HS
original_ds_train['hate_speech'] = original_ds_train['hate_speech'].astype('category')

others = original_ds_train['hate_speech'].value_counts().index[1:]
label = 'HS'

original_ds_train['hate_speech'] = original_ds_train['hate_speech'].cat.add_categories([label])
original_ds_train['hate_speech'] = original_ds_train['hate_speech'].replace(others, label)
ax=sns.countplot(x='hate_speech', data=original_ds_train)

# %%
#count the number of dublicates
print(original_ds_train['Tweet'].duplicated().sum())
# Out:
# 0

# %%
original_ds_train['Tweet']=original_ds_train['Tweet'].str.replace('@USER','')
original_ds_train['Tweet']=original_ds_train['Tweet'].str.replace('<LF>','')
original_ds_train['Tweet']=original_ds_train['Tweet'].str.replace('URL','')

original_ds_train
# Out:
#         id                                              Tweet offensive  \
# 0        2                  وصارت فطاير البقالات غذاء صحي 👎🏻    NOT_OFF
# 1        3   روحي لبريده تلقين اشباه كثير بس ماحد زيكم مشف...       OFF
# 2        4                   مش باين حاجه خالص 😣مش عارف بقى 😔   NOT_OFF
# 3        5  #اليوم_الاثنين👏 يقولك :%90  من المسلمين عندهم ...   NOT_OFF
# 4        6                      حمدلله ماحطها في فمي اساسا😷🤢    NOT_OFF
# ...    ...                                                ...       ...
# 8551  8883                                      الله يلعنهم 🤢       OFF
# 8552  8884  واحد سال زوجته بعد كم سنة زواج:- حبيبتي كم رجا...   NOT_OFF
# 8553  8885   يالله روح زي الشاطر واحذف الشو الي سويته بس ع...       OFF
# 8554  8886  لـمـا الـكـلاب تـهـوهـو عـلـيـك🐶🐶 وأنـت_اللـى_...   NOT_OFF
# 8555  8887  #بايع_الكليجاالله ياخذكم ي بنات خلوني اترزق ال...   NOT_OFF
#
#      hate_speech      VLG      VIO
# 0         NOT_HS  NOT_VLG  NOT_VIO
# 1         NOT_HS  NOT_VLG  NOT_VIO
# 2         NOT_HS  NOT_VLG  NOT_VIO
# 3         NOT_HS  NOT_VLG  NOT_VIO
# 4         NOT_HS  NOT_VLG  NOT_VIO
# ...          ...      ...      ...
# 8551         NaN  NOT_VLG  NOT_VIO
# 8552         NaN  NOT_VLG  NOT_VIO
# 8553         NaN  NOT_VLG  NOT_VIO
# 8554         NaN  NOT_VLG  NOT_VIO
# 8555         NaN  NOT_VLG  NOT_VIO
#
# [8556 rows x 6 columns]

# %% [markdown]
# # wordcloud

# %%
tweet_text=' '.join(original_ds_train['Tweet'])
tweet_text = arabic_reshaper.reshape(tweet_text)
tweet_text = get_display(tweet_text)
wordcloud = WordCloud(font_path='fonts/NotoNaskhArabic.ttf').generate(tweet_text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title('All the Dataset')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\rabee\OneDrive\Desktop\arabic_sent_aanalysis-main\arabic_sent_aanalysis\EDA\OSACT2022_eda.ipynb Cell 11 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/rabee/OneDrive/Desktop/arabic_sent_aanalysis-main/arabic_sent_aanalysis/EDA/OSACT2022_eda.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> tweet_text=' '.join(original_ds_train['Tweet'])
# ----> <a href='vscode-notebook-cell:/c%3A/Users/rabee/OneDrive/Desktop/arabic_sent_aanalysis-main/arabic_sent_aanalysis/EDA/OSACT2022_eda.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> tweet_text = arabic_reshaper.reshape(tweet_text)
#       <a href='vscode-notebook-cell:/c%3A/Users/rabee/OneDrive/Desktop/arabic_sent_aanalysis-main/arabic_sent_aanalysis/EDA/OSACT2022_eda.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> tweet_text = get_display(tweet_text)
#       <a href='vscode-notebook-cell:/c%3A/Users/rabee/OneDrive/Desktop/arabic_sent_aanalysis-main/arabic_sent_aanalysis/EDA/OSACT2022_eda.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a> wordcloud = WordCloud(font_path='fonts/NotoNaskhArabic.ttf').generate(tweet_text)
#
# File c:\Users\rabee\AppData\Local\Programs\Python\Python310\lib\site-packages\arabic_reshaper\arabic_reshaper.py:197, in ArabicReshaper.reshape(self, text)
#     193 forms = self._get_ligature_forms_from_re_group_index(
#     194     group_index
#     195 )
#     196 a, b = match.span()
# --> 197 a_form = output[a][FORM]
#     198 b_form = output[b - 1][FORM]
#     199 ligature_form = None
تبن أحسن لك ياطبل ياطار للبنات والفساد انطم ياذكر بعيد كل البعد عن الرجوله ياحيف بس اذا عاجبك اللي صار ليه ماوديت اهلك وخليتهم يعطون رايهم ويصورون ولد الناس اللي ابتلش من اللي تصفق لهم الخلا مير الخلا ياتسلب👎🏻 #بايع_الكليجا قلة أدب وادوختونا صدق🤢 بيجيبون لي امراض الدنيا وانا توني بعمر الزهور💩💔💔💔💔💔💔💔 #ب ...

# %%
tweet_text=' '.join(origin_ds[origin_ds.Class=='normal']['Tweet'])
tweet_text = arabic_reshaper.reshape(tweet_text)
tweet_text = get_display(tweet_text)
wordcloud = WordCloud(font_path='fonts/NotoNaskhArabic.ttf').generate(tweet_text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title('normal Class')
plt.show()

# %%
tweet_text=' '.join(origin_ds[origin_ds.Class=='hate']['Tweet'])
tweet_text = arabic_reshaper.reshape(tweet_text)
tweet_text = get_display(tweet_text)
wordcloud = WordCloud(font_path='fonts/NotoNaskhArabic.ttf').generate(tweet_text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title('hate Class')
plt.show()

# %%
tweet_text=' '.join(origin_ds[origin_ds.Class=='abusive']['Tweet'])
tweet_text = arabic_reshaper.reshape(tweet_text)
tweet_text = get_display(tweet_text)
wordcloud = WordCloud(font_path='fonts/NotoNaskhArabic.ttf').generate(tweet_text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title('abusive Class')
plt.show()

# %% [markdown]
# # most frequents words

# %%
#remove stop words from the dataframe and addint it new column
copy_origin_ds=origin_ds
copy_origin_ds['tweet_without_stopwords'] = copy_origin_ds['Tweet'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stopwords.words('arabic'))]))
copy_origin_ds
# Out:
#                                                   Tweet    Class  \
# 0     الوزير جبران باسيل تاج راسك يا جربان ممنوع بعد...  abusive
# 1     صديقي انت ابن جامعه اللعبه اكبر من داعش اللعبه...   normal
# 2     و مصلحة لبنان تبدأ باستخراج النفط و الغاز لوقف...   normal
# 3                       وليد جنبلاط كاتب الحكمة يا قذر   abusive
# 4     شو بتلبقلك كلمة خنزير بتجي مفصله على قياسك وشك...  abusive
# ...                                                 ...      ...
# 5841                              أمير المليشيا مش خائن   normal
# 5842                               صدقت يناسبك جدا جدا    normal
# 5843                            لبخليني حب باسيل شغلتين   normal
# 5844  ليش تيوس الإمارت والسعودية مع السوريين واليمني...     hate
# 5845  مش دفاعاً عن جبران باسيل بس كان لازم تحط المقط...   normal
#
#                                 tweet_without_stopwords
# 0     الوزير جبران باسيل تاج راسك جربان ممنوع اليوم ...
# 1     صديقي انت ابن جامعه اللعبه اكبر داعش اللعبه سن...
# 2     مصلحة لبنان تبدأ باستخراج النفط الغاز لوقف الش...
# 3                           وليد جنبلاط كاتب الحكمة قذر
# 4          شو بتلبقلك كلمة خنزير بتجي مفصله قياسك وشكلك
# ...                                                 ...
# 5841                              أمير المليشيا مش خائن
# 5842                                صدقت يناسبك جدا جدا
# 5843                            لبخليني حب باسيل شغلتين
# 5844  ليش تيوس الإمارت والسعودية السوريين واليمنيين ...
# 5845  مش دفاعاً جبران باسيل لازم تحط المقطع عالقليلة...
#
# [5846 rows x 3 columns]

# %%
word_df=pd.DataFrame(' '.join(origin_ds['tweet_without_stopwords']).lower().split(),columns=['words'])
word_df
# Out:
#          words
# 0       الوزير
# 1        جبران
# 2        باسيل
# 3          تاج
# 4         راسك
# ...        ...
# 58008  هالكلمة
# 58009    لنفهم
# 58010       شو
# 58011      قال
# 58012     بدقة
#
# [58013 rows x 1 columns]

# %%
top_all=pd.Series(' '.join(copy_origin_ds['tweet_without_stopwords']).lower().split()).value_counts()[:20].to_dict()
for old_key in list(top_all):
    new_key=arabic_reshaper.reshape(old_key)
    new_key = get_display(new_key)
    top_all[new_key] = top_all.pop(old_key)

plt.figure(figsize=(15,8))
plt.bar(top_all.keys(), top_all.values())
# Out:
# <BarContainer object of 20 artists>

# %%
from turtle import width


def GetTopWord(k,hclass):
    word_df=pd.DataFrame(' '.join(copy_origin_ds['tweet_without_stopwords']).lower().split(),columns=['words'])
    top_all=pd.Series(' '.join(copy_origin_ds[copy_origin_ds['Class']==hclass]['tweet_without_stopwords']).lower().split()).value_counts()[:k].to_dict()
    for old_key in list(top_all):
        new_key=arabic_reshaper.reshape(old_key)
        new_key = get_display(new_key)
        top_all[new_key] = top_all.pop(old_key)

    my_df = pd.DataFrame(top_all.items())
    plt.figure(figsize=(15,8))
    ax = sns.barplot(x=0, y=1, data=my_df,color='blue')
    ax.set(xlabel = 'tokens', ylabel='%', title=f'Most common {hclass} tokens in the L-HSAB ')
    #plt.bar(top_all.keys(), top_all.values())
    #plt.title(f'top {k} words in the {hclass} class')

# %%
GetTopWord(20,'normal')

# %%
GetTopWord(20,'abusive')

# %%
GetTopWord(20,'hate')

# %% [markdown]
# # plot emoji count

# %%
def split_count(text):
    emoji_list = []
    data = regex.findall(r'\X', text)
    for word in data:
        if any(char in emoji.UNICODE_EMOJI for char in word):
            emoji_list.append(word)
    
    return emoji_list

# %%
text = origin_ds['Tweet']
emoji_list= [] 
for t in text:
  emoji_list=emoji_list+split_count(t)



emojies_dict=dict(Counter(emoji_list))
emoji_counts=pd.DataFrame(emojies_dict.items(),columns=['Emoji','Count'])
emoji_counts.sort_values('Count',ascending=False)[:5]



fig = go.Figure()


fig.add_trace(go.Scatter(y=emoji_counts['Emoji'][:5],
                x=emoji_counts['Count'][:5],
                name='Emoji Counts',
                marker_color='white',
                orientation='h',
                text=emoji_counts['Emoji'][:5],
                textposition='top center',
                mode='markers+text',
                textfont=dict(size=30),
                ))

fig.update_yaxes(visible =False, range=[0, len(emoji_counts)+1])
fig.update_xaxes(title='Number of Times Used')
fig.update_layout(
    autosize=False,height=700)

# %% [markdown]
# # number  of  tokens  per  tweet

# %%
NOTPT_df=origin_ds
NOTPT_df['number_of_tokens'] = NOTPT_df['Tweet'].str.split().str.len()
sns.boxplot(data=NOTPT_df, x='Class', y='number_of_tokens')
# Out:
# <AxesSubplot:xlabel='Class', ylabel='number_of_tokens'>
